# %% [markdown]
# <a href="https://colab.research.google.com/github/KitkatKratika/Weather/blob/main/Weather_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **PROJECT 1: Weather Report**

# %%
import numpy as np
import pandas as pd

# %%
data= pd.read_csv('/Project-1 (Weather Dataset).csv')
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# Q1:- Find all the unique "Wind Speed" values in the Data?

# %%
data["Wind Speed_km/h"].nunique()
# Out:
# 34

# %% [markdown]
# Q2:- Find the no. of times when the "Weather is exactly Fog"?

# %%
data.head(5)
data[data.Weather=="Fog"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
#       Visibility_km  Press_kPa Weather
# ...

# %% [markdown]
# Q3:- Find the number of times when the "Wind Speed" was exactly 9Km/hr?

# %%
data[data["Wind Speed_km/h"] == 9]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 8        1/1/2012 8:00    -1.4              -3.6         85                9
# 10      1/1/2012 10:00    -1.0              -2.3         91                9
# 12      1/1/2012 12:00    -0.2              -2.0         88                9
# 77       1/4/2012 5:00   -18.6             -24.0         62                9
# ...                ...     ...               ...        ...              ...
# 8737   12/30/2012 1:00    -9.4             -10.5         92                9
# 8738   12/30/2012 2:00    -9.3             -10.4         92                9
# 8762   12/31/2012 2:00   -10.1             -13.4         77                9
# 8771  12/31/2012 11:00    -6.7              -7.9         91                9
# 8775  12/31/2012 15:00    -2.3              -4.6         84                9
#
#       Visibility_km  Press_kPa       Weather
# ...

# %% [markdown]
# Q4:- Find out all the null values in the data?

# %%
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64
